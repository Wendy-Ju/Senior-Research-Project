# %%
import os
import zipfile
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut

import sys 
import json
import glob
import random
import collections
import time
import re
import math
import numpy as np
import pandas as pd
import cv2

# %% [markdown]
# ### Load data

# %%
# Lets read the train data and the train labels. 
train_data_directory = 'D:/Brain_Tumor_Data/train'
data_directory = 'D:/Brain_Tumor_Data'
IMAGE_SIZE = 128
NUM_IMAGES = 64
def load_dicom_image(path, img_size=IMAGE_SIZE, voi_lut=True, rotate=0):
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    if voi_lut:
        data = apply_voi_lut(dicom.pixel_array, dicom)
    else:
        data = dicom.pixel_array
        
    if rotate > 0:
        rot_choices = [0, cv2.ROTATE_90_CLOCKWISE, cv2.ROTATE_90_COUNTERCLOCKWISE, cv2.ROTATE_180]
        data = cv2.rotate(data, rot_choices[rotate])
        
    data = cv2.resize(data, (img_size, img_size))
    return data


def load_dicom_images_3d(scan_id, num_imgs=NUM_IMAGES, img_size=IMAGE_SIZE, mri_type="T1w", split="test", rotate=0):

    files = sorted(glob.glob(f"{data_directory}/{split}/{scan_id}/{mri_type}/*.dcm"), 
               key=lambda var:[int(x) if x.isdigit() else x for x in re.findall(r'[^0-9]|[0-9]+', var)])

    middle = len(files)//2
    num_imgs2 = num_imgs//2
    p1 = max(0, middle - num_imgs2)
    p2 = min(len(files), middle + num_imgs2)
    img3d = np.stack([load_dicom_image(f, rotate=rotate) for f in files[p1:p2]]).T 
    if img3d.shape[-1] < num_imgs:
        n_zero = np.zeros((img_size, img_size, num_imgs - img3d.shape[-1]))
        img3d = np.concatenate((img3d,  n_zero), axis = -1)
        
    if np.min(img3d) < np.max(img3d):
        img3d = img3d - np.min(img3d)
        img3d = img3d / np.max(img3d)
            
    return np.expand_dims(img3d,0)

# %%
a = load_dicom_images_3d("00001")
print(a.shape)
print(np.min(a), np.max(a), np.mean(a), np.median(a))
image = a[0]
print("Dimension of the CT scan is:", image.shape)
plt.imshow(np.squeeze(image[:, :, 15]), cmap="gray")
# Out:
# (1, 128, 128, 64)
# 0.0 1.0 0.3975705077603092 0.7483399765459943
# Dimension of the CT scan is: (128, 128, 64)

# %%
df_train_labels = pd.read_csv('D:/Brain_Tumor_Data/_labels.csv')
df_train_labels.head()
# Out:
#    BraTS21ID  MGMT_value
# 0          0           1
# 1          2           1
# 2          3           0
# 3          5           1
# 4          6           1

# %%
train_data_directory = 'D:/Brain_Tumor_Data/train'
print(min(os.listdir(train_data_directory)), max(os.listdir(train_data_directory)))
# Out:
# 00000 01010

# %%
total_training_scans_T1 = np.array([load_dicom_images_3d(a, split = 'train', mri_type="T1w") for a in os.listdir(train_data_directory)])

# %%
len(total_training_scans_T1)
# Out:
# 585

# %%
print(total_training_scans_T1.shape)
print(len(total_training_scans_T1))
image = total_training_scans_T1[20]
print("Dimension of the CT scan is:", image.shape)
plt.imshow(np.squeeze(image[:, :, 25]), cmap="gray")
# Out:
# (585, 1, 128, 128, 64)
# 585
# Dimension of the CT scan is: (1, 128, 128, 64)

# %%
# Split data in the ratio 70-30 for training and validation.
x_train_T1 = np.array([train.T for train in total_training_scans_T1[:410]])
x_val_T1 = np.array([train.T for train in total_training_scans_T1[410:]])

# %%
print(f"The shape of train: {x_train_T1.shape}")
# Out:
# The shape of train: (410, 64, 128, 128, 1)

# %%
print(f"The shape of val: {x_val_T1.shape}")
# Out:
# The shape of val: (175, 64, 128, 128, 1)

# %%
total_training_labels = df_train_labels["MGMT_value"].to_list()

# %%
total_training_labels = total_training_labels[:585]

# %%
len(total_training_labels)
# Out:
# 585

# %%
y_train = total_training_labels[:410]
y_val = total_training_labels[410:]

# %% [markdown]
# ### Model

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2)
    ]
)

# %%
def get_model(drop_out, with_data_aug, width=128, height=128, depth=64):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((depth,width, height,1))
    if (with_data_aug):
        x = data_augmentation(inputs)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(drop_out)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")
    return model

# %%
with tf.device('/device:GPU:0'):
    auc_list = []
    auc_with_data_aug = []
    count = 0
    for i in np.arange(0, 1, 0.1):
        for j in np.arange(2):
            # Build model.
            model = get_model(drop_out = i, with_data_aug = j, width=128, height=128, depth=64)

            # Compile model.
            initial_learning_rate = 0.0001
            lr_schedule = keras.optimizers.schedules.ExponentialDecay(
                initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
            )
            model.compile(
                loss="binary_crossentropy",
                optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
                metrics=[keras.metrics.AUC(), keras.metrics.BinaryAccuracy(name='acc')],
            )

            # Define callbacks.
            checkpoint_cb = keras.callbacks.ModelCheckpoint(
               f"Drop_out_{i}.h5", save_best_only=True
            )
            # 
            early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)  # TODO

            # Train the model, doing validation at the end of each epoch
            epochs = 10
            history = model.fit(
                tf.data.Dataset.from_tensor_slices((x_train_T1, y_train)).batch(4),
                validation_data=tf.data.Dataset.from_tensor_slices((x_val_T1,y_val)).batch(4),
                epochs=epochs,
                shuffle=True,
                verbose=2,
                callbacks=[checkpoint_cb, early_stopping_cb],
            )
            if (count > 0):
                if (j):
                    auc_with_data_aug.append(history.history[f'val_auc_{count}'][-1])
                else:
                    auc_list.append(history.history[f'val_auc_{count}'][-1])
            else:
                if (j):
                    auc_with_data_aug.append(history.history['val_auc'][-1])
                else:
                    auc_list.append(history.history['val_auc'][-1])
            
            count += 1
        print(i)
# Out:
# Epoch 1/10
# 103/103 - 53s - loss: 0.7168 - auc: 0.5410 - acc: 0.5195 - val_loss: 0.7154 - val_auc: 0.4675 - val_acc: 0.4343 - 53s/epoch - 514ms/step
# Epoch 2/10
# 103/103 - 31s - loss: 0.6849 - auc: 0.5985 - acc: 0.5659 - val_loss: 0.7745 - val_auc: 0.4681 - val_acc: 0.4343 - 31s/epoch - 296ms/step
# Epoch 3/10
# 103/103 - 31s - loss: 0.6558 - auc: 0.6506 - acc: 0.6073 - val_loss: 0.7584 - val_auc: 0.4645 - val_acc: 0.4343 - 31s/epoch - 297ms/step
# Epoch 4/10
# 103/103 - 31s - loss: 0.6181 - auc: 0.7167 - acc: 0.6610 - val_loss: 0.7626 - val_auc: 0.4282 - val_acc: 0.4457 - 31s/epoch - 300ms/step
# Epoch 5/10
# 103/103 - 31s - loss: 0.5900 - auc: 0.7614 - acc: 0.7146 - val_loss: 0.7454 - val_auc: 0.4314 - val_acc: 0.4457 - 31s/epoch - 305ms/step
# Epoch 6/10
# 103/103 - 32s - loss: 0.5596 - auc: 0.8023 - acc: 0.7268 - val_loss: 0.7663 - val_auc: 0.4322 - val_acc: 0.5314 - 32s/epoch - 313ms/step
# Epoch 7/10
# 103/103 - 32s - loss: 0.5257 - auc: 0.8391 - acc: 0.7634 - val_loss: 0.8200 - val_auc: 0.4316 - val_acc: 0.4514 - 32s/epoch - 306ms/step
# Epoch 8/10
# 103/103 - 31s - loss: 0.4954 - auc: 0.8718 - acc: 0.8073 - val_loss: 0.8743 - val_auc: 0.4361 - val_acc: 0.4571 - 31s/epoch - 304ms/step
# Epoch 9/10
# 103/103 - 32s - loss: 0.4715 - auc: 0.8877 - acc: 0.8073 - val_loss: 0.8965 - val_auc: 0.4480 - val_acc: 0.4629 - 32s/epoch - 309ms/step
# Epoch 10/10
# 103/103 - 31s - loss: 0.4393 - auc: 0.9141 - acc: 0.8341 - val_loss: 0.9419 - val_auc: 0.4693 - val_acc: 0.4686 - 31s/epoch - 303ms/step
# Epoch 1/10
# 103/103 - 33s - loss: 0.7202 - auc_1: 0.5332 - acc: 0.5195 - val_loss: 0.6880 - val_auc_1: 0.4865 - val_acc: 0.5600 - 33s/epoch - 322ms/step
# Epoch 2/10
# 103/103 - 32s - loss: 0.6931 - auc_1: 0.5786 - acc: 0.5634 - val_loss: 0.7169 - val_auc_1: 0.4888 - val_acc: 0.4343 - 32s/epoch - 307ms/step
# Epoch 3/10
# 103/103 - 32s - loss: 0.6562 - auc_1: 0.6509 - acc: 0.6073 - val_loss: 0.7043 - val_auc_1: 0.4682 - val_acc: 0.5029 - 32s/epoch - 306ms/step
# Epoch 4/10
# 103/103 - 32s - loss: 0.6329 - auc_1: 0.6975 - acc: 0.6488 - val_loss: 0.7569 - val_auc_1: 0.4754 - val_acc: 0.4114 - 32s/epoch - 315ms/step
# Epoch 5/10
# 103/103 - 34s - loss: 0.5980 - auc_1: 0.7563 - acc: 0.6927 - val_loss: 0.7190 - val_auc_1: 0.4747 - val_acc: 0.4857 - 34s/epoch - 326ms/step
# Epoch 6/10
# 103/103 - 36s - loss: 0.5687 - auc_1: 0.8025 - acc: 0.7415 - val_loss: 0.7079 - val_auc_1: 0.5120 - val_acc: 0.5371 - 36s/epoch - 348ms/step
# Epoch 7/10
# 103/103 - 34s - loss: 0.5520 - auc_1: 0.8184 - acc: 0.7561 - val_loss: 0.7302 - val_auc_1: 0.4972 - val_acc: 0.5257 - 34s/epoch - 326ms/step
# Epoch 8/10
# 103/103 - 33s - loss: 0.5299 - auc_1: 0.8398 - acc: 0.7756 - val_loss: 0.8115 - val_auc_1: 0.4216 - val_acc: 0.4857 - 33s/epoch - 317ms/step
# Epoch 9/10
# 103/103 - 36s - loss: 0.5061 - auc_1: 0.8602 - acc: 0.7805 - val_loss: 0.8613 - val_auc_1: 0.4254 - val_acc: 0.4571 - 36s/epoch - 345ms/step
# Epoch 10/10
# 103/103 - 32s - loss: 0.4861 - auc_1: 0.8809 - acc: 0.7951 - val_loss: 0.9359 - val_auc_1: 0.4256 - val_acc: 0.4229 - 32s/epoch - 310ms/step
# 0.0
# Epoch 1/10
# 103/103 - 33s - loss: 0.7233 - auc_2: 0.5327 - acc: 0.5293 - val_loss: 0.6984 - val_auc_2: 0.4729 - val_acc: 0.4229 - 33s/epoch - 320ms/step
# Epoch 2/10
# 103/103 - 31s - loss: 0.6978 - auc_2: 0.5747 - acc: 0.5415 - val_loss: 0.7231 - val_auc_2: 0.4468 - val_acc: 0.4343 - 31s/epoch - 297ms/step
# Epoch 3/10
# 103/103 - 31s - loss: 0.6683 - auc_2: 0.6311 - acc: 0.5878 - val_loss: 0.7161 - val_auc_2: 0.4351 - val_acc: 0.4514 - 31s/epoch - 300ms/step
# Epoch 4/10
# 103/103 - 31s - loss: 0.6376 - auc_2: 0.6834 - acc: 0.6146 - val_loss: 0.7538 - val_auc_2: 0.4268 - val_acc: 0.4400 - 31s/epoch - 306ms/step
# Epoch 5/10
# 103/103 - 33s - loss: 0.6160 - auc_2: 0.7286 - acc: 0.6634 - val_loss: 0.8081 - val_auc_2: 0.4215 - val_acc: 0.4457 - 33s/epoch - 316ms/step
# Epoch 6/10
# 103/103 - 33s - loss: 0.5844 - auc_2: 0.7731 - acc: 0.6829 - val_loss: 0.7785 - val_auc_2: 0.4327 - val_acc: 0.4457 - 33s/epoch - 316ms/step
# Epoch 7/10
# 103/103 - 32s - loss: 0.5592 - auc_2: 0.8106 - acc: 0.7244 - val_loss: 0.7773 - val_auc_2: 0.4304 - val_acc: 0.4457 - 32s/epoch - 310ms/step
# Epoch 8/10
# 103/103 - 32s - loss: 0.5387 - auc_2: 0.8305 - acc: 0.7415 - val_loss: 0.8406 - val_auc_2: 0.4145 - val_acc: 0.4400 - 32s/epoch - 314ms/step
# Epoch 9/10
# 103/103 - 33s - loss: 0.5171 - auc_2: 0.8536 - acc: 0.7732 - val_loss: 0.8673 - val_auc_2: 0.4423 - val_acc: 0.4686 - 33s/epoch - 320ms/step
# Epoch 4/10
# 103/103 - 32s - loss: 0.6784 - auc_10: 0.6142 - acc: 0.5878 - val_loss: 0.7814 - val_auc_10: 0.4697 - val_acc: 0.4514 - 32s/epoch - 312ms/step
# Epoch 5/10
# 103/103 - 31s - loss: 0.6431 - auc_10: 0.6729 - acc: 0.6341 - val_loss: 0.7364 - val_auc_10: 0.4557 - val_acc: 0.4514 - 31s/epoch - 300ms/step
# Epoch 6/10
# 103/103 - 33s - loss: 0.6392 - auc_10: 0.6756 - acc: 0.6268 - val_loss: 0.7321 - val_auc_10: 0.4454 - val_acc: 0.4457 - 33s/epoch - 318ms/step
# Epoch 7/10
# 103/103 - 32s - loss: 0.6073 - auc_10: 0.7241 - acc: 0.6610 - val_loss: 0.7556 - val_auc_10: 0.4358 - val_acc: 0.4686 - 32s/epoch - 310ms/step
# Epoch 8/10
# 103/103 - 34s - loss: 0.6088 - auc_10: 0.7363 - acc: 0.6829 - val_loss: 0.7887 - val_auc_10: 0.4268 - val_acc: 0.4400 - 34s/epoch - 327ms/step
# Epoch 9/10
# 103/103 - 32s - loss: 0.5754 - auc_10: 0.7719 - acc: 0.6878 - val_loss: 0.7546 - val_auc_10: 0.4340 - val_acc: 0.4686 - 32s/epoch - 314ms/step
# Epoch 10/10
# 103/103 - 34s - loss: 0.5623 - auc_10: 0.7841 - acc: 0.7049 - val_loss: 0.8188 - val_auc_10: 0.4236 - val_acc: 0.4343 - 34s/epoch - 331ms/step
# Epoch 1/10
# 103/103 - 33s - loss: 0.7289 - auc_11: 0.5295 - acc: 0.5195 - val_loss: 0.6931 - val_auc_11: 0.4930 - val_acc: 0.5371 - 33s/epoch - 325ms/step
# Epoch 2/10
# 103/103 - 33s - loss: 0.7120 - auc_11: 0.5547 - acc: 0.5415 - val_loss: 0.7168 - val_auc_11: 0.4908 - val_acc: 0.4343 - 33s/epoch - 317ms/step
# Epoch 3/10
# 103/103 - 32s - loss: 0.6952 - auc_11: 0.5851 - acc: 0.5829 - val_loss: 0.9483 - val_auc_11: 0.4862 - val_acc: 0.4343 - 32s/epoch - 306ms/step
# Epoch 4/10
# 103/103 - 32s - loss: 0.6573 - auc_11: 0.6677 - acc: 0.6366 - val_loss: 0.7443 - val_auc_11: 0.4656 - val_acc: 0.4057 - 32s/epoch - 314ms/step
# Epoch 5/10
# 103/103 - 32s - loss: 0.6691 - auc_11: 0.6405 - acc: 0.6024 - val_loss: 0.7363 - val_auc_11: 0.4153 - val_acc: 0.4286 - 32s/epoch - 312ms/step
# Epoch 6/10
# 103/103 - 33s - loss: 0.6500 - auc_11: 0.6513 - acc: 0.6024 - val_loss: 0.7120 - val_auc_11: 0.4500 - val_acc: 0.4686 - 33s/epoch - 316ms/step
# Epoch 7/10
# 103/103 - 32s - loss: 0.6243 - auc_11: 0.7155 - acc: 0.6707 - val_loss: 0.7516 - val_auc_11: 0.4274 - val_acc: 0.4971 - 32s/epoch - 307ms/step
# Epoch 8/10
# 103/103 - 32s - loss: 0.6130 - auc_11: 0.7319 - acc: 0.6732 - val_loss: 0.7907 - val_auc_11: 0.4085 - val_acc: 0.4629 - 32s/epoch - 307ms/step
# 103/103 - 33s - loss: 0.7115 - auc_13: 0.5587 - acc: 0.5439 - val_loss: 0.9323 - val_auc_13: 0.4708 - val_acc: 0.4343 - 33s/epoch - 316ms/step
# Epoch 4/10
# 103/103 - 32s - loss: 0.6934 - auc_13: 0.5921 - acc: 0.5707 - val_loss: 0.8922 - val_auc_13: 0.4567 - val_acc: 0.4343 - 32s/epoch - 307ms/step
# Epoch 5/10
# 103/103 - 32s - loss: 0.6589 - auc_13: 0.6382 - acc: 0.5854 - val_loss: 0.8480 - val_auc_13: 0.4339 - val_acc: 0.4400 - 32s/epoch - 315ms/step
# Epoch 6/10
# 103/103 - 33s - loss: 0.6602 - auc_13: 0.6566 - acc: 0.6098 - val_loss: 0.7516 - val_auc_13: 0.4628 - val_acc: 0.4457 - 33s/epoch - 317ms/step
# Epoch 7/10
# 103/103 - 33s - loss: 0.6427 - auc_13: 0.6809 - acc: 0.6293 - val_loss: 0.7937 - val_auc_13: 0.4498 - val_acc: 0.5314 - 33s/epoch - 321ms/step
# Epoch 8/10
# 103/103 - 32s - loss: 0.6192 - auc_13: 0.6993 - acc: 0.6512 - val_loss: 0.7466 - val_auc_13: 0.4640 - val_acc: 0.5029 - 32s/epoch - 315ms/step
# Epoch 9/10
# 103/103 - 32s - loss: 0.6244 - auc_13: 0.6934 - acc: 0.6244 - val_loss: 0.7345 - val_auc_13: 0.4490 - val_acc: 0.4914 - 32s/epoch - 307ms/step
# Epoch 10/10
# 103/103 - 31s - loss: 0.6182 - auc_13: 0.7196 - acc: 0.6659 - val_loss: 0.7727 - val_auc_13: 0.4322 - val_acc: 0.4629 - 31s/epoch - 299ms/step
# 0.6000000000000001
# Epoch 1/10
# 103/103 - 33s - loss: 0.7282 - auc_14: 0.5369 - acc: 0.5220 - val_loss: 0.6868 - val_auc_14: 0.4608 - val_acc: 0.5657 - 33s/epoch - 323ms/step
# Epoch 2/10
# 103/103 - 31s - loss: 0.7042 - auc_14: 0.5708 - acc: 0.5366 - val_loss: 0.6947 - val_auc_14: 0.4682 - val_acc: 0.5257 - 31s/epoch - 305ms/step
# Epoch 3/10
# 103/103 - 32s - loss: 0.7006 - auc_14: 0.5849 - acc: 0.5463 - val_loss: 0.7144 - val_auc_14: 0.4676 - val_acc: 0.4343 - 32s/epoch - 307ms/step
# Epoch 4/10
# 103/103 - 33s - loss: 0.7305 - auc_14: 0.5659 - acc: 0.5585 - val_loss: 0.7109 - val_auc_14: 0.4562 - val_acc: 0.4686 - 33s/epoch - 316ms/step
# Epoch 5/10
# 103/103 - 35s - loss: 0.6952 - auc_14: 0.6001 - acc: 0.5878 - val_loss: 0.7602 - val_auc_14: 0.4324 - val_acc: 0.4457 - 35s/epoch - 336ms/step
# Epoch 6/10
# 103/103 - 34s - loss: 0.6754 - auc_14: 0.6027 - acc: 0.5585 - val_loss: 0.7362 - val_auc_14: 0.4267 - val_acc: 0.4514 - 34s/epoch - 329ms/step
# Epoch 7/10
# 103/103 - 33s - loss: 0.6677 - auc_14: 0.6311 - acc: 0.5756 - val_loss: 0.7573 - val_auc_14: 0.4097 - val_acc: 0.4343 - 33s/epoch - 321ms/step
# Epoch 8/10
# 103/103 - 31s - loss: 0.8253 - auc_19: 0.4981 - acc: 0.5244 - val_loss: 0.7628 - val_auc_19: 0.4728 - val_acc: 0.4343 - 31s/epoch - 298ms/step
# Epoch 3/10
# 103/103 - 32s - loss: 0.7772 - auc_19: 0.5340 - acc: 0.5171 - val_loss: 0.7177 - val_auc_19: 0.4625 - val_acc: 0.4171 - 32s/epoch - 308ms/step
# Epoch 4/10
# 103/103 - 31s - loss: 0.7986 - auc_19: 0.5442 - acc: 0.5488 - val_loss: 0.7724 - val_auc_19: 0.4693 - val_acc: 0.4171 - 31s/epoch - 303ms/step
# Epoch 5/10
# 103/103 - 31s - loss: 0.7973 - auc_19: 0.5239 - acc: 0.5146 - val_loss: 0.7330 - val_auc_19: 0.4380 - val_acc: 0.4171 - 31s/epoch - 302ms/step
# Epoch 6/10
# 103/103 - 31s - loss: 0.7553 - auc_19: 0.5457 - acc: 0.5341 - val_loss: 0.7258 - val_auc_19: 0.4688 - val_acc: 0.4629 - 31s/epoch - 300ms/step
# Epoch 7/10
# 103/103 - 30s - loss: 0.7453 - auc_19: 0.5486 - acc: 0.5463 - val_loss: 0.7186 - val_auc_19: 0.4555 - val_acc: 0.4571 - 30s/epoch - 296ms/step
# Epoch 8/10
# 103/103 - 31s - loss: 0.7277 - auc_19: 0.5739 - acc: 0.5488 - val_loss: 0.7355 - val_auc_19: 0.4083 - val_acc: 0.4114 - 31s/epoch - 302ms/step
# Epoch 9/10
# 103/103 - 31s - loss: 0.7432 - auc_19: 0.5356 - acc: 0.5317 - val_loss: 0.7122 - val_auc_19: 0.4274 - val_acc: 0.5029 - 31s/epoch - 302ms/step
# Epoch 10/10
# 103/103 - 31s - loss: 0.7425 - auc_19: 0.5816 - acc: 0.5537 - val_loss: 0.7791 - val_auc_19: 0.4918 - val_acc: 0.4343 - 31s/epoch - 303ms/step
# 0.9

# %%
drop_out_values = np.arange(0, 1, 0.1)

plt.figure(figsize=(16,7))
plt.subplot(1, 2, 1)
plt.plot(drop_out_values, auc_list)
plt.xlabel('Drop Out Value')
plt.ylabel('AUC')
plt.xlim([0, 1])
plt.ylim([0.4, 0.6])
plt.title("No Data Augmentation")

plt.subplot(1, 2, 2)
plt.plot(drop_out_values, auc_with_data_aug)
plt.xlabel('Drop Out Value')
plt.ylabel('AUC')
plt.xlim([0, 1])
plt.ylim([0.4, 0.6])
plt.title('With Data Augmentation')

plt.show()

# %%
print(f"Best AUC with Data_Aug: {np.max(auc_with_data_aug)} at Drop_out = {round(drop_out_values[np.argmax(auc_with_data_aug)], 2)}" )
print(f"Best AUC No Data_Aug: {np.max(auc_list)} at Drop_out = {drop_out_values[np.argmax(auc_list)]}")
# Out:
# Best AUC with Data_Aug: 0.49175968766212463 at Drop_out = 0.9
# Best AUC No Data_Aug: 0.49455079436302185 at Drop_out = 0.4

# %% [markdown]
# Drop out 0: (Data-Aug) Epoch 6: 0.512
#
# Drop out 0.2: (Data-Aug) Epoch 9: 0.5112
#
# Drop out 0.4: (Data-Aug) Epoch 1: 0.5149
#
# Drop out 0.5: (no Data-Aug) Epoch 1: 0.54 !!!
#
# Drop out 0.7: (Data-Aug) Epoch 2:  0.52
